# %% [markdown]
# # Welkom bij de onderzoeks pipeline voor het vak Data Science.
# ----
#
# ### Dit onderzoek is opgezet door groep 6 van klas V2C:
# - Sebastiaan Jansen
# - Mustafa Toprak
# - Skott de Koster
#
# #### Dit data onderzoek is gebaseerd op de dataset over films. Het bevat een aantal onderzoeksvragen die wij zullen behandelen:
# - In hoeverre is de omzet van een film te voorspellen op basis van de populariteit op Facebook en IMDB zelf?
# - Tot hoeverre variëren  de genres van de films waarin een acteur speelt verspreid over zijn/haar carrière?
# - Hoeveel effect heeft de lengte van een trailer op de omzet van de film?
# - Is een film succesvoller op basis van het aantal likes die een acteur (of acteurs) heeft/hebben op facebook?
# - Welke regisseurs boeken de meeste winst?
# - Wat is de totale winst van alle films per jaar?
#
# Deze vragen zullen allemaal worden behandeld in dit onderzoek.

# %% [markdown]
# ## Stap 1: Data collection

# %% [markdown]
# De dataset is aan ons gegeven door de Hogeschool Utrecht als onderdeel van de opdracht. Deze dataset houd een groot csv bestand in met onder andere de film titel, genre en een paar belangrijke acteurs. We hebben dus nu de data verzameld en moeten het nu inlezen.

# %% [markdown]
# ---

# %% [markdown]
# ## Stap 2: Data processing

# %% [markdown]
# We gaan nu de dataset inlezen en verwerken om het beter te kunnen bekijken. Om te beginnen importeren we de benodigde Python libraries:

# %%
# Deze libraries zijn voor het verwerken van de data.
import numpy as np
import pandas as pd

# Deze libraries zijn voor het verkrijgen van YouTube video gegevens, dit komt later aan bod.
import pafy
import youtube_dl
import datetime

# %% [markdown]
# Vervolgens lezen we de eerste (interne) dataset in. Hiervoor gebruiken we pandas.read_csv en slaan we dit op in de dataframe "films".
# Aangezien de dataset erg groot is, laten we voor nu alleen de eerste en laatste paar rijen zien. Dit doen we door "films" aan te roepen:

# %%
films = pd.read_csv('movie.csv', sep=",")
films
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 5038  ...                  6.0  English   Canada             NaN          NaN
# 5039  ...                359.0  English      USA           TV-14          NaN
# 5040  ...                  3.0  English      USA             NaN       1400.0
# 5041  ...                  9.0  English      USA           PG-13          NaN
# 5042  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 5038      2013.0                  470.0        7.7           NaN
# 5039         NaN                  593.0        7.5         16.00
# 5040      2013.0                    0.0        6.3           NaN
# 5041      2012.0                  719.0        6.3          2.35
# 5042      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [5043 rows x 28 columns]

# %% [markdown]
# Hetzelfde doen we met de tweede (externe) dataset:

# %%
films2 = pd.read_csv('ml-youtube.csv', sep=",")
films2
# Out:
#          youtubeId  movieId                                              title
# 0      K26_sDKnvMU        1                                   Toy Story (1995)
# 1      3LPANjHlPxo        2                                     Jumanji (1995)
# 2      rEnOoWs3FuA        3                            Grumpier Old Men (1995)
# 3      j9xml1CxgXI        4                           Waiting to Exhale (1995)
# 4      ltwvKLnj1B4        5                 Father of the Bride Part II (1995)
# ...            ...      ...                                                ...
# 25618  -oB6DN5dYWo   131252  Forklift Driver Klaus: The First Day on the Jo...
# 25619  DK7KQ-gEdl4   131256                      Feuer, Eis & Dosenbier (2002)
# 25620  v29P-wchMZQ   131258                                 The Pirates (2014)
# 25621  dAz-nZ65jYU   131260                                Rentun Ruusu (2001)
# 25622  YWmbl_7VVYk   131262                                   Innocence (2014)
#
# [25623 rows x 3 columns]

# %% [markdown]
# We zien dus dat de eerste dataset bestaat uit 5043 films, dit moeten we nu combineren met de tweede dataset. Maar de tweede dataset heeft veel meer rows en een iets andere vorm van filmtitel. Dit moeten we dus oplossen, en ook de andere problemen zoals de NaN en duplicate waarden.

# %% [markdown]
# ---

# %% [markdown]
# # Stap 3: Data cleaning

# %% [markdown]
# We gaan nu de data schoon maken. Om te beginnen schonen we de eerste dataset op door alle data die niet relevant is te verwijderen:

# %%
to_drop = ['color','facenumber_in_poster','country','aspect_ratio','language','content_rating','plot_keywords']

films.drop(to_drop, inplace=True, axis=1)

films2.drop('movieId', inplace=True, axis=1)

# %%
# We verwijderen de rijen met NaN gegevens in beide datasets, aangezien dit data is die we niet kunnen gebruiken.
films = films.dropna()
films2 = films2.dropna()

# %%
# We halen alle duplicates eruit.
films.drop_duplicates(subset="movie_title")
films2.drop_duplicates(subset="title")
# Out:
#          youtubeId                                              title
# 0      K26_sDKnvMU                                   Toy Story (1995)
# 1      3LPANjHlPxo                                     Jumanji (1995)
# 2      rEnOoWs3FuA                            Grumpier Old Men (1995)
# 3      j9xml1CxgXI                           Waiting to Exhale (1995)
# 4      ltwvKLnj1B4                 Father of the Bride Part II (1995)
# ...            ...                                                ...
# 25618  -oB6DN5dYWo  Forklift Driver Klaus: The First Day on the Jo...
# 25619  DK7KQ-gEdl4                      Feuer, Eis & Dosenbier (2002)
# 25620  v29P-wchMZQ                                 The Pirates (2014)
# 25621  dAz-nZ65jYU                                Rentun Ruusu (2001)
# 25622  YWmbl_7VVYk                                   Innocence (2014)
#
# [25607 rows x 2 columns]

# %%
# We slicen de laatste 7 characters van de title column (het jaar dat de film uitkwam) in de tweede dataset weg,
# zodat de column overeen komt met de column in de eerste dataset.
films.update(films['movie_title'].str[:-1])
films2.update(films2['title'].str[:-7])

# %%
# We setten de indexes van beide datasets naar de titel van de films.
films.set_index('movie_title', inplace=True)
films2.set_index('title', inplace=True)

# %%
films.index = films.index.map(str)
films2.index = films2.index.map(str)

# %%
# We sorteren beide datasets zodat de waardes gelijk zullen zijn.
films = films.sort_index()
films2 = films2.sort_index()

# %% [markdown]
# Nu ziet de eerste dataset er zo uit:

# %%
films
# Out:
#                                director_name  num_critic_for_reviews  \
# movie_title
# 10 Cloverfield Lane         Dan Trachtenberg                   411.0
# 10 Days in a Madhouse          Timothy Hines                     1.0
# 10 Things I Hate About You        Gil Junger                   133.0
# 102 Dalmatians                    Kevin Lima                    84.0
# 10th & Wolf                   Robert Moresco                    26.0
# ...                                      ...                     ...
# [Rec] 2                      Jaume Balagueró                   222.0
# eXistenZ                    David Cronenberg                   196.0
# xXx                                Rob Cohen                   191.0
# xXx: State of the Union         Lee Tamahori                    77.0
# Æon Flux                        Karyn Kusama                   178.0
#
#                             duration  director_facebook_likes  \
# movie_title
# 10 Cloverfield Lane            104.0                     16.0
# 10 Days in a Madhouse          111.0                      0.0
# 10 Things I Hate About You      97.0                     19.0
# 102 Dalmatians                 100.0                     36.0
# 10th & Wolf                    107.0                     53.0
# ...                              ...                      ...
# [Rec] 2                         85.0                     57.0
# eXistenZ                       115.0                      0.0
# xXx                            132.0                    357.0
# xXx: State of the Union        101.0                     93.0
# Æon Flux                        93.0                     45.0
#
#                             actor_3_facebook_likes        actor_2_name  \
# movie_title
# 10 Cloverfield Lane                           82.0  John Gallagher Jr.
# 10 Days in a Madhouse                        247.0       Kelly LeBrock
# 10 Things I Hate About You                   835.0        Heath Ledger
# 102 Dalmatians                               439.0           Eric Idle
# 10th & Wolf                                  463.0         Brad Renfro
# ...                                            ...                 ...
# [Rec] 2                                        6.0         Pablo Rosso
# eXistenZ                                     716.0        Sarah Polley
# xXx                                          212.0                 Eve
# xXx: State of the Union                      218.0           Nona Gaye
# Æon Flux                                     352.0      Sophie Okonedo
#
#                             actor_1_facebook_likes        gross  \
# movie_title
# 10 Cloverfield Lane                        14000.0   71897215.0
# 10 Days in a Madhouse                       1000.0      14616.0
# 10 Things I Hate About You                 23000.0   38176108.0
# 102 Dalmatians                              2000.0   66941559.0
# 10th & Wolf                                  954.0      53481.0
# ...                                            ...          ...
# [Rec] 2                                       37.0      27024.0
# eXistenZ                                    1000.0    2840417.0
# xXx                                        14000.0  141204016.0
# xXx: State of the Union                      287.0   26082914.0
# Æon Flux                                    9000.0   25857987.0
#
#                                                           genres  \
# movie_title
# 10 Cloverfield Lane         Drama|Horror|Mystery|Sci-Fi|Thriller
# 10 Days in a Madhouse                                      Drama
# 10 Things I Hate About You                  Comedy|Drama|Romance
# 102 Dalmatians                           Adventure|Comedy|Family
# 10th & Wolf                                 Crime|Drama|Thriller
# ...                                                          ...
# [Rec] 2                                                   Horror
# eXistenZ                                  Horror|Sci-Fi|Thriller
# xXx                                    Action|Adventure|Thriller
# xXx: State of the Union          Action|Adventure|Crime|Thriller
# Æon Flux                                           Action|Sci-Fi
#
#                                     actor_1_name  num_voted_users  \
# movie_title
# 10 Cloverfield Lane               Bradley Cooper           126893
# 10 Days in a Madhouse        Christopher Lambert              314
# 10 Things I Hate About You  Joseph Gordon-Levitt           222099
# 102 Dalmatians                     Ioan Gruffudd            26413
# 10th & Wolf                        Brian Dennehy             5557
# ...                                          ...              ...
# [Rec] 2                       Jonathan D. Mellor            55597
# eXistenZ                    Jennifer Jason Leigh            77493
# xXx                                   Vin Diesel           142569
# xXx: State of the Union             Sunny Mabrey            51349
# Æon Flux                         Charlize Theron           110614
#
#                             cast_total_facebook_likes      actor_3_name  \
# movie_title
# 10 Cloverfield Lane                             14504   Sumalee Montano
# 10 Days in a Madhouse                            2059  Alexandra Callas
# 10 Things I Hate About You                      37907     Andrew Keegan
# 102 Dalmatians                                   4182        Jim Carter
# 10th & Wolf                                      2512        Dash Mihok
# ...                                               ...               ...
# [Rec] 2                                            73        Andrea Ros
# eXistenZ                                         2990     Callum Rennie
# xXx                                             14790     Leila Arcieri
# xXx: State of the Union                           993            Xzibit
# Æon Flux                                        10185   Paterson Joseph
#
#                                                               movie_imdb_link  \
# movie_title
# 10 Cloverfield Lane         http://www.imdb.com/title/tt1179933/?ref_=fn_t...
# 10 Days in a Madhouse       http://www.imdb.com/title/tt3453052/?ref_=fn_t...
# 10 Things I Hate About You  http://www.imdb.com/title/tt0147800/?ref_=fn_t...
# 102 Dalmatians              http://www.imdb.com/title/tt0211181/?ref_=fn_t...
# 10th & Wolf                 http://www.imdb.com/title/tt0360323/?ref_=fn_t...
# ...                                                                       ...
# [Rec] 2                     http://www.imdb.com/title/tt1245112/?ref_=fn_t...
# eXistenZ                    http://www.imdb.com/title/tt0120907/?ref_=fn_t...
# xXx                         http://www.imdb.com/title/tt0295701/?ref_=fn_t...
# xXx: State of the Union     http://www.imdb.com/title/tt0329774/?ref_=fn_t...
# Æon Flux                    http://www.imdb.com/title/tt0402022/?ref_=fn_t...
#
#                             num_user_for_reviews      budget  title_year  \
# movie_title
# 10 Cloverfield Lane                        440.0  15000000.0      2016.0
# 10 Days in a Madhouse                       10.0  12000000.0      2015.0
# 10 Things I Hate About You                 549.0  16000000.0      1999.0
# 102 Dalmatians                              77.0  85000000.0      2000.0
# 10th & Wolf                                 34.0   8000000.0      2006.0
# ...                                          ...         ...         ...
# [Rec] 2                                    148.0   5600000.0      2009.0
# eXistenZ                                   527.0  31000000.0      1999.0
# xXx                                        737.0  70000000.0      2002.0
# xXx: State of the Union                    213.0  87000000.0      2005.0
# Æon Flux                                   532.0  62000000.0      2005.0
#
#                             actor_2_facebook_likes  imdb_score  \
# movie_title
# 10 Cloverfield Lane                          338.0         7.3
# 10 Days in a Madhouse                        445.0         7.5
# 10 Things I Hate About You                 13000.0         7.2
# 102 Dalmatians                               795.0         4.8
# 10th & Wolf                                  551.0         6.4
# ...                                            ...         ...
# [Rec] 2                                        9.0         6.6
# eXistenZ                                     900.0         6.8
# xXx                                          223.0         5.8
# xXx: State of the Union                      233.0         4.3
# Æon Flux                                     460.0         5.5
#
#                             movie_facebook_likes
# movie_title
# 10 Cloverfield Lane                        33000
# 10 Days in a Madhouse                      26000
# 10 Things I Hate About You                 10000
# 102 Dalmatians                               372
# 10th & Wolf                                  294
# ...                                          ...
# [Rec] 2                                     4000
# eXistenZ                                    6000
# xXx                                        10000
# xXx: State of the Union                        0
# Æon Flux                                       0
#
# [3879 rows x 20 columns]

# %% [markdown]
# En ziet de tweede dataset er zo uit:

# %%
films2
# Out:
#                                                       youtubeId
# title
# "Great Performances" Cats                           fpIzXaJS18s
# #chicagoGirl: The Social Network Takes on a Dic...  Dq31M_MUtU4
# $ (Dollars)                                         yDLMPb9rspo
# $5 a Day                                            DsC3fxNTyno
# $9.99                                               Ls4t_y6lTUo
# ...                                                         ...
# ¡Three Amigos!                                      WUTl8DSYUQA
# À l'aventure                                        7kXP7YFM5Gw
# À nos amours                                        z_gcsG4-5vw
# À nous la liberté (Freedom for Us)                  6PZkEo6xnGc
# Åsa-Nisse - Wälkom to Knohult                       knxZ4bco9XE
#
# [25623 rows x 1 columns]

# %% [markdown]
# Nu gaan we beide datasets samenvoegen. Het idee is om de youtubeId column van de tweede dataset te verwerken in de eerste dataset.

# %%
films = pd.merge(films, films2, left_index=True, right_index=True)
films
# Out:
#                                director_name  num_critic_for_reviews  \
# 10 Things I Hate About You        Gil Junger                   133.0
# 102 Dalmatians                    Kevin Lima                    84.0
# 10th & Wolf                   Robert Moresco                    26.0
# 12 Rounds                       Renny Harlin                   113.0
# 12 Years a Slave               Steve McQueen                   597.0
# ...                                      ...                     ...
# Zoolander                        Ben Stiller                   135.0
# Zoom                            Peter Hewitt                    63.0
# eXistenZ                    David Cronenberg                   196.0
# xXx                                Rob Cohen                   191.0
# xXx: State of the Union         Lee Tamahori                    77.0
#
#                             duration  director_facebook_likes  \
# 10 Things I Hate About You      97.0                     19.0
# 102 Dalmatians                 100.0                     36.0
# 10th & Wolf                    107.0                     53.0
# 12 Rounds                      108.0                    212.0
# 12 Years a Slave               134.0                      0.0
# ...                              ...                      ...
# Zoolander                       90.0                      0.0
# Zoom                            83.0                     12.0
# eXistenZ                       115.0                      0.0
# xXx                            132.0                    357.0
# xXx: State of the Union        101.0                     93.0
#
#                             actor_3_facebook_likes         actor_2_name  \
# 10 Things I Hate About You                   835.0         Heath Ledger
# 102 Dalmatians                               439.0            Eric Idle
# 10th & Wolf                                  463.0          Brad Renfro
# 12 Rounds                                    347.0         Ashley Scott
# 12 Years a Slave                             500.0        Scoot McNairy
# ...                                            ...                  ...
# Zoolander                                   8000.0  Alexander Skarsgård
# Zoom                                         690.0             Rip Torn
# eXistenZ                                     716.0         Sarah Polley
# xXx                                          212.0                  Eve
# xXx: State of the Union                      218.0            Nona Gaye
#
#                             actor_1_facebook_likes        gross  \
# 10 Things I Hate About You                 23000.0   38176108.0
# 102 Dalmatians                              2000.0   66941559.0
# 10th & Wolf                                  954.0      53481.0
# 12 Rounds                                    969.0   12232937.0
# 12 Years a Slave                            2000.0   56667870.0
# ...                                            ...          ...
# Zoolander                                  14000.0   45162741.0
# Zoom                                        2000.0   11631245.0
# eXistenZ                                    1000.0    2840417.0
# xXx                                        14000.0  141204016.0
# xXx: State of the Union                      287.0   26082914.0
#
#                                                      genres  \
# 10 Things I Hate About You             Comedy|Drama|Romance
# 102 Dalmatians                      Adventure|Comedy|Family
# 10th & Wolf                            Crime|Drama|Thriller
# 12 Rounds                             Action|Crime|Thriller
# 12 Years a Slave                    Biography|Drama|History
# ...                                                     ...
# Zoolander                                            Comedy
# Zoom                         Action|Adventure|Family|Sci-Fi
# eXistenZ                             Horror|Sci-Fi|Thriller
# xXx                               Action|Adventure|Thriller
# xXx: State of the Union     Action|Adventure|Crime|Thriller
#
#                                     actor_1_name  ...  \
# 10 Things I Hate About You  Joseph Gordon-Levitt  ...
# 102 Dalmatians                     Ioan Gruffudd  ...
# 10th & Wolf                        Brian Dennehy  ...
# 12 Rounds                            Taylor Cole  ...
# 12 Years a Slave               Quvenzhané Wallis  ...
# ...                                          ...  ...
# Zoolander                         Milla Jovovich  ...
# Zoom                                Kevin Zegers  ...
# eXistenZ                    Jennifer Jason Leigh  ...
# xXx                                   Vin Diesel  ...
# xXx: State of the Union             Sunny Mabrey  ...
#
#                             cast_total_facebook_likes      actor_3_name  \
# 10 Things I Hate About You                      37907     Andrew Keegan
# 102 Dalmatians                                   4182        Jim Carter
# 10th & Wolf                                      2512        Dash Mihok
# 12 Rounds                                        2799        Nick Gomez
# 12 Years a Slave                                 4251      Taran Killam
# ...                                               ...               ...
# Zoolander                                       34565      Will Ferrell
# Zoom                                             5022  Thomas F. Wilson
# eXistenZ                                         2990     Callum Rennie
# xXx                                             14790     Leila Arcieri
# xXx: State of the Union                           993            Xzibit
#
#                                                               movie_imdb_link  \
# 10 Things I Hate About You  http://www.imdb.com/title/tt0147800/?ref_=fn_t...
# 102 Dalmatians              http://www.imdb.com/title/tt0211181/?ref_=fn_t...
# 10th & Wolf                 http://www.imdb.com/title/tt0360323/?ref_=fn_t...
# 12 Rounds                   http://www.imdb.com/title/tt1160368/?ref_=fn_t...
# 12 Years a Slave            http://www.imdb.com/title/tt2024544/?ref_=fn_t...
# ...                                                                       ...
# Zoolander                   http://www.imdb.com/title/tt0196229/?ref_=fn_t...
# Zoom                        http://www.imdb.com/title/tt0383060/?ref_=fn_t...
# eXistenZ                    http://www.imdb.com/title/tt0120907/?ref_=fn_t...
# xXx                         http://www.imdb.com/title/tt0295701/?ref_=fn_t...
# xXx: State of the Union     http://www.imdb.com/title/tt0329774/?ref_=fn_t...
#
#                            num_user_for_reviews      budget  title_year  \
# 10 Things I Hate About You                549.0  16000000.0      1999.0
# 102 Dalmatians                             77.0  85000000.0      2000.0
# 10th & Wolf                                34.0   8000000.0      2006.0
# 12 Rounds                                 113.0  22000000.0      2009.0
# 12 Years a Slave                          695.0  20000000.0      2013.0
# ...                                         ...         ...         ...
# Zoolander                                 523.0  28000000.0      2001.0
# Zoom                                      113.0  35000000.0      2006.0
# eXistenZ                                  527.0  31000000.0      1999.0
# xXx                                       737.0  70000000.0      2002.0
# xXx: State of the Union                   213.0  87000000.0      2005.0
#
#                             actor_2_facebook_likes  imdb_score  \
# 10 Things I Hate About You                 13000.0         7.2
# 102 Dalmatians                               795.0         4.8
# 10th & Wolf                                  551.0         6.4
# 12 Rounds                                    794.0         5.6
# 12 Years a Slave                             660.0         8.1
# ...                                            ...         ...
# Zoolander                                  10000.0         6.6
# Zoom                                         826.0         4.2
# eXistenZ                                     900.0         6.8
# xXx                                          223.0         5.8
# xXx: State of the Union                      233.0         4.3
#
#                             movie_facebook_likes    youtubeId
# 10 Things I Hate About You                 10000  wRo7iUQMcTM
# 102 Dalmatians                               372  cGHh59Oj8eU
# 10th & Wolf                                  294  12wdi73Kbxk
# 12 Rounds                                      0  Mp3Aqe8FrNE
# 12 Years a Slave                           83000  v2fDTOdWuQQ
# ...                                          ...          ...
# Zoolander                                      0  t1krvnjzV4w
# Zoom                                         494  5y7q5b3WyEc
# eXistenZ                                    6000  IEuykd38iNE
# xXx                                        10000  Spx-Mx3xhYY
# xXx: State of the Union                        0  TS8Pl4tsJGQ
#
# [2966 rows x 21 columns]

# %% [markdown]
# Je kunt zien dat er nu nog minder films zijn. Dit is omdat de films die zijn weggehaald geen trailer hebben, en dus niet bruikbaar zijn. <br>
# We gaan de gemergede dataset nu verkennen en analyseren.
